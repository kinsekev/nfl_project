# %%
import requests
from selenium import webdriver
import pandas as pd
import time
from bs4 import BeautifulSoup
from pprint import pprint

# %%
cols = ['game_date', 'home_team', 'away_team', 'home_score', 'away_score', 'game_time', 'stadium', 'duration', 
        'home_first_downs', 'away_first_downs', 'home_num_rushes', 'home_rush_yards', 'home_rush_tds', 'away_num_rushes',
        'away_rush_yards', 'away_rush_tds', 'home_pass_comp', 'home_pass_att', 'home_pass_yards', 'home_pass_tds',
        'home_pass_ints', 'away_pass_comp', 'away_pass_att', 'away_pass_yards', 'away_pass_tds', 'away_pass_ints',
        'home_sacks_allowed', 'home_sacks_yards_allowed', 'away_sacks_allowed', 'away_sacks_yards_allowed', 
        'home_net_pass_yards', 'away_net_pass_yards', 'home_total_yards', 'away_total_yards', 'home_fumbles', 
        'home_fumbles_lost', 'away_fumbles', 'away_fumbles_lost', 'home_turnovers', 'away_turnovers', 'home_num_penallity',
        'home_penallity_yards', 'away_num_penallity', 'away_penallity_yards', 'home_third_downs', 'home_third_downs_converted',
        'away_third_downs', 'away_third_downs_converted', 'home_fourth_downs', 'home_fourth_downs_converted', 
        'away_fourth_downs', 'away_fourth_downs_converted', 'home_time_possession', 'away_time_possession', 'won_toss',
        'roof', 'surface', 'attendance', 'weather', 'fav_team', 'handicap', 'points_line', 
        'points_line_result']

# %%
BASE_URL = 'https://www.pro-football-reference.com/'
URL = 'https://www.pro-football-reference.com/years/' + str(YEAR) + '/week_'

def scrape_data(driver, year):
    
    YEAR = year

    for week in range(1, 22):

        week_data = []
        games_url = URL + str(week) + '.htm'
        print(games_url)
        driver.get(games_url)

        time.sleep(5)

        html = driver.execute_script('return document.documentElement.outerHTML')
        soup = BeautifulSoup(html, 'html.parser')

        games = soup.find_all('table', attrs = {'class': 'teams'})
        links = sum([game.find_all('td', attrs={'class': 'right gamelink'}) for game in games], [])
        links = sum([link.find_all('a', href=True) for link in links], [])
        links = list(set([a['href'][1:] for a in links]))
        links = [link for link in links if link[10:14] in [str(YEAR), str(YEAR + 1)]]

        for i in range(len(links)):

            print(BASE_URL + links[i])

            driver.get(BASE_URL + links[i])

            html = driver.execute_script('return document.documentElement.outerHTML')
            soup = BeautifulSoup(html, 'html.parser')

            time.sleep(5)

            scorebox = soup.find('div', attrs = {'class': 'scorebox'})

            teams = [team.get_text() for team in scorebox.find_all('a', attrs = {'itemprop': 'name'})]
            home_team = teams[0]
            away_team = teams[1]

            print(home_team)
            print(away_team)

            scores = [int(score.get_text()) for score in scorebox.find_all('div', attrs = {'class': 'score'})]
            home_score = int(scores[0])
            away_score = int(scores[1])

            print(home_score)
            print(away_score)

            scorebox_meta_dct = {}
            scorebox_meta = soup.find('div', attrs = {'class': 'scorebox_meta'})
            scorebox_meta = scorebox_meta.find_all('div')

            for i in range(1, len(scorebox_meta)-1):

                print(scorebox_meta[i].get_text())
                print(scorebox_meta[i].get_text().split(': ', 1))

                a, b = scorebox_meta[i].get_text().split(': ', 1)
                scorebox_meta_dct[a] = b

            print(scorebox_meta_dct)

            game_date = scorebox_meta[0].get_text()
            start_time = scorebox_meta[1].get_text().split(': ', 1)[1]
            stadium = scorebox_meta_dct['Stadium'] if 'Stadium' in scorebox_meta_dct else ''
            game_length = scorebox_meta_dct['Time of Game'] if 'Time of Game' in scorebox_meta_dct else ''

            print(game_date)
            print(start_time)
            print(stadium)
            print(game_length)

            time.sleep(5)

            # team stats
            team_stats = soup.find('table', attrs = {'class': 'add_controls stats_table'})
            team_stats = team_stats.find_all('td', attrs = {'class': 'center'})

            away_first_downs = int(team_stats[0].get_text())
            home_first_downs = int(team_stats[1].get_text())

            if '--' in team_stats[2].get_text():
                t_stat_2 = team_stats[2].get_text().replace('--', '-')
            else:
                t_stat_2 = team_stats[2].get_text()

            away_num_rushes, away_rush_yards, away_rush_tds = list(map(int, t_stat_2.split('-')))


            if '--' in team_stats[3].get_text():
                t_stat_3 = team_stats[3].get_text().replace('--', '-')
            else:
                t_stat_3 = team_stats[3].get_text()

            home_num_rushes, home_rush_yards, home_rush_tds = list(map(int, t_stat_3.split('-')))

            if '--' in team_stats[4].get_text():
                t_stat_4 = team_stats[4].get_text().replace('--', '-')
            else:
                t_stat_4 = team_stats[4].get_text()


            away_pass_comp, away_pass_att, away_pass_yards, away_pass_tds, away_pass_ints = list(map(int, t_stat_4.split('-')))
            home_pass_comp, home_pass_att, home_pass_yards, home_pass_tds, home_pass_ints = list(map(int, team_stats[5].get_text().split('-')))
            away_sacks_allowed, away_sacks_yards_allowed = list(map(int, team_stats[6].get_text().split('-')))
            home_sacks_allowed, home_sacks_yards_allowed = list(map(int, team_stats[7].get_text().split('-')))
            away_net_pass_yards, home_net_pass_yards = int(team_stats[8].get_text()), int(team_stats[9].get_text())
            away_total_yards, home_total_yards = int(team_stats[10].get_text()), int(team_stats[11].get_text())
            away_fumbles, away_fumbles_lost = list(map(int, team_stats[12].get_text().split('-')))
            home_fumbles, home_fumbles_lost = list(map(int, team_stats[13].get_text().split('-')))
            away_turnovers, home_turnovers = int(team_stats[14].get_text()), int(team_stats[15].get_text())
            away_num_penallity, away_penallity_yards = list(map(int, team_stats[16].get_text().split('-')))
            home_num_penallity, home_penallity_yards = list(map(int, team_stats[17].get_text().split('-')))
            away_third_downs, away_third_downs_converted = list(map(int, team_stats[18].get_text().split('-')))
            home_third_downs, home_third_downs_converted = list(map(int, team_stats[19].get_text().split('-')))
            away_fourth_downs, away_fourth_downs_converted = list(map(int, team_stats[20].get_text().split('-')))
            home_fourth_downs, home_fourth_downs_converted = list(map(int, team_stats[21].get_text().split('-')))
            away_time_possession, home_time_possession = team_stats[22].get_text(), team_stats[23].get_text()


            # game info
            game_info_dct = {}
            game_info = soup.find_all('table', attrs={'class': 'suppress_all sortable stats_table now_sortable'})[0]
            game_info_left = game_info.find_all('th')
            game_info_right = game_info.find_all('td')[1:]

            for l, r in zip(game_info_left, game_info_right):
                game_info_dct[l.get_text()] = r.get_text()

            print(game_info_dct)

            won_toss = game_info_dct['Won Toss'] if 'Won Toss' in game_info_dct else ''
            roof = game_info_dct['Roof'] if 'Roof' in game_info_dct else ''
            surface = game_info_dct['Surface'] if 'Surface' in game_info_dct else ''
            attendance = game_info_dct['Attendance'] if 'Attendance' in game_info_dct else 0
            weather = game_info_dct['Weather'] if 'Weather' in game_info_dct else ''
            vegas_line = game_info_dct['Vegas Line'] if 'Vegas Line' in game_info_dct else ''
            over_under = game_info_dct['Over/Under'] if 'Over/Under' in game_info_dct else ''

            # vegas line    
            neg = vegas_line.find('-')
            fav_team = vegas_line[:neg-1]
            handicap = vegas_line[neg:]

            # over/under
            inner_brac = over_under.find('(')
            outer_brac = over_under.find(')')
            points_line = float(over_under[:inner_brac-1])
            points_line_result = over_under[inner_brac+1:outer_brac]

            game_data = [
                game_date,
                home_team,
                away_team,
                home_score,
                away_score,
                start_time,
                stadium,
                game_length,
                home_first_downs,
                away_first_downs,
                home_num_rushes,
                home_rush_yards,
                home_rush_tds,
                away_num_rushes,
                away_rush_yards,
                away_rush_tds,
                home_pass_comp,
                home_pass_att,
                home_pass_yards,
                home_pass_tds,
                home_pass_ints,
                away_pass_comp,
                away_pass_att,
                away_pass_yards,
                away_pass_tds,
                away_pass_ints,
                home_sacks_allowed,
                home_sacks_yards_allowed,
                away_sacks_allowed,
                away_sacks_yards_allowed,
                home_net_pass_yards,
                away_net_pass_yards,
                home_total_yards,
                away_total_yards,
                home_fumbles,
                home_fumbles_lost,
                away_fumbles,
                away_fumbles_lost,
                home_turnovers,
                away_turnovers,
                home_num_penallity,
                home_penallity_yards,
                away_num_penallity,
                away_penallity_yards,
                home_third_downs,
                home_third_downs_converted,
                away_third_downs,
                away_third_downs_converted,
                home_fourth_downs,
                home_fourth_downs_converted,
                away_fourth_downs,
                away_fourth_downs_converted,
                home_time_possession,
                away_time_possession,
                won_toss,
                roof,
                surface,
                attendance,
                weather,
                fav_team,
                handicap,
                points_line,
                points_line_result
            ]
            print(game_data)
            week_data.append(game_data)


        df = pd.DataFrame(week_data, columns=cols)

        df['game_date'] = pd.to_datetime(df['game_date'])

        df['game_time'] = pd.to_datetime(df['game_time'])
        df['game_time'] = df['game_time'].dt.time

        df['duration'] = pd.to_datetime(df['duration'], format='%M:%S').dt.time
        df['home_time_possession'] = pd.to_datetime(df['home_time_possession'], format='%M:%S').dt.time
        df['away_time_possession'] = pd.to_datetime(df['away_time_possession'], format='%M:%S').dt.time

        df.sort_values(by=['game_date', 'game_time'], inplace=True)

        df.to_csv('./scraped_data/' + str(YEAR) + '/week_' + str(week) + '.csv', index=False)

    driver.close()
# Out:
# https://www.pro-football-reference.com/years/2002/week_1.htm
# https://www.pro-football-reference.com/boxscores/200209080mia.htm
# Miami Dolphins
# Detroit Lions
# 49
# 21
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Pro Player Stadium
# ['Stadium', 'Pro Player Stadium ']
# Attendance: 72,216
# ['Attendance', '72,216']
# Time of Game: 3:02
# ['Time of Game', '3:02']
# {'Start Time': '1:04pm', 'Stadium': 'Pro Player Stadium ', 'Attendance': '72,216', 'Time of Game': '3:02'}
# Sunday Sep 8, 2002
# 1:04pm
# Pro Player Stadium
# 3:02
# {'Won Toss': 'Dolphins', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:02', 'Attendance': '72,216', 'Weather': '87 degrees, relative humidity 69%, wind 12 mph, wind chill 0', 'Vegas Line': 'Miami Dolphins -9.5', 'Over/Under': '35.5 (over)'}
# ['Sunday Sep 8, 2002', 'Miami Dolphins', 'Detroit Lions', 49, 21, '1:04pm', 'Pro Player Stadium ', '3:02', 27, 15, 41, 182, 3, 19, 51, 2, 18, 27, 207, 3, 0, 17, 36, 220, 1, 1, 0, 0, 3, 14, 207, 206, 389, 257, 2, 0, 2, 1, 0, 2, 4, 54, 6, 68, 6, 12, 7, 14, 1, 1, 0, 1, '34:24', '25:36', 'Dolphins', 'outdoors', 'grass', '72,216', '87 degrees, relative humidity 69%, wind 12 mph, wind chill 0', 'Miami Dolphins', '-9.5', 35.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209080den.htm
# Denver Broncos
# St. Louis Rams
# 23
# 16
# Start Time: 4:17pm
# ['Start Time', '4:17pm']
# Stadium: Invesco Field at Mile High
# ['Stadium', 'Invesco Field at Mile High ']
# Attendance: 75,710
# ['Attendance', '75,710']
# Time of Game: 2:51
# ['Time of Game', '2:51']
# {'Start Time': '4:17pm', 'Stadium': 'Invesco Field at Mile High ', 'Attendance': '75,710', 'Time of Game': '2:51'}
# Sunday Sep 8, 2002
# 4:17pm
# Invesco Field at Mile High
# 2:51
# {'Won Toss': 'Rams', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '2:51', 'Attendance': '75,710', 'Weather': '83 degrees, relative humidity 33%, wind 4 mph, wind chill 0', 'Vegas Line': 'St. Louis Rams -3.0', 'Over/Under': '51.0 (under)'}
# ['Sunday Sep 8, 2002', 'Denver Broncos', 'St. Louis Rams', 23, 16, '4:17pm', 'Invesco Field at Mile High ', '2:51', 18, 15, 26, 104, 0, 13, 32, 1, 18, 27, 202, 2, 2, 32, 41, 315, 0, 1, 4, 15, 3, 20, 187, 295, 291, 327, 1, 0, 2, 1, 2, 2, 3, 31, 6, 44, 2, 10, 3, 12, 1, 1, 0, 1, '28:14', '31:46', 'Rams', 'outdoors', 'grass', '75,710', '83 degrees, relative humidity 33%, wind 4 mph, wind chill 0', 'St. Louis Rams', '-3.0', 51.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209080cin.htm
# Cincinnati Bengals
# San Diego Chargers
# 6
# 34
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Paul Brown Stadium
# ['Stadium', 'Paul Brown Stadium ']
# Attendance: 53,705
# ['Attendance', '53,705']
# Time of Game: 2:57
# ['Time of Game', '2:57']
# {'Start Time': '1:04pm', 'Stadium': 'Paul Brown Stadium ', 'Attendance': '53,705', 'Time of Game': '2:57'}
# Sunday Sep 8, 2002
# 1:04pm
# Paul Brown Stadium
# 2:57
# {'Won Toss': 'Chargers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '2:57', 'Attendance': '53,705', 'Weather': '90 degrees, relative humidity 60%, wind 7 mph, wind chill 0', 'Vegas Line': 'Cincinnati Bengals -3.0', 'Over/Under': '37.0 (over)'}
# ['Sunday Sep 8, 2002', 'Cincinnati Bengals', 'San Diego Chargers', 6, 34, '1:04pm', 'Paul Brown Stadium ', '2:57', 13, 27, 13, 36, 0, 45, 241, 2, 18, 31, 198, 0, 1, 15, 19, 160, 2, 0, 4, 31, 1, 0, 167, 160, 203, 401, 0, 0, 0, 0, 1, 0, 9, 57, 4, 39, 4, 11, 6, 10, 0, 0, 0, 0, '22:12', '37:48', 'Chargers', 'outdoors', 'grass', '53,705', '90 degrees, relative humidity 60%, wind 7 mph, wind chill 0', 'Cincinnati Bengals', '-3.0', 37.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209080buf.htm
# Buffalo Bills
# New York Jets
# 31
# 37
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Ralph Wilson Stadium
# ['Stadium', 'Ralph Wilson Stadium ']
# Attendance: 72,751
# ['Attendance', '72,751']
# Time of Game: 3:25
# ['Time of Game', '3:25']
# {'Start Time': '1:04pm', 'Stadium': 'Ralph Wilson Stadium ', 'Attendance': '72,751', 'Time of Game': '3:25'}
# Sunday Sep 8, 2002
# 1:04pm
# Ralph Wilson Stadium
# 3:25
# {'Won Toss': 'Jets', 'Won OT Toss': 'Jets', 'Roof': 'outdoors', 'Surface': 'astroturf', 'Duration': '3:25', 'Attendance': '72,751', 'Weather': '86 degrees, relative humidity 75%, wind 6 mph, wind chill 0', 'Vegas Line': 'New York Jets -3.0', 'Over/Under': '43.0 (over)'}
# ['Sunday Sep 8, 2002', 'Buffalo Bills', 'New York Jets', 31, 37, '1:04pm', 'Ralph Wilson Stadium ', '3:25', 26, 18, 32, 142, 3, 14, 73, 0, 26, 39, 271, 1, 2, 24, 30, 210, 2, 0, 4, 29, 3, 17, 242, 193, 384, 266, 1, 1, 1, 1, 3, 1, 10, 82, 10, 90, 7, 17, 2, 8, 2, 2, 0, 0, '39:08', '21:06', 'Jets', 'outdoors', 'astroturf', '72,751', '86 degrees, relative humidity 75%, wind 6 mph, wind chill 0', 'New York Jets', '-3.0', 43.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209080cle.htm
# Cleveland Browns
# Kansas City Chiefs
# 39
# 40
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Cleveland Browns Stadium
# ['Stadium', 'Cleveland Browns Stadium ']
# Attendance: 72,938
# ['Attendance', '72,938']
# Time of Game: 3:20
# ['Time of Game', '3:20']
# {'Start Time': '1:04pm', 'Stadium': 'Cleveland Browns Stadium ', 'Attendance': '72,938', 'Time of Game': '3:20'}
# Sunday Sep 8, 2002
# 1:04pm
# Cleveland Browns Stadium
# 3:20
# {'Won Toss': 'Chiefs', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:20', 'Attendance': '72,938', 'Weather': '86 degrees, relative humidity 48%, no wind, wind chill 0', 'Vegas Line': 'Cleveland Browns -2.0', 'Over/Under': '36.0 (over)'}
# ['Sunday Sep 8, 2002', 'Cleveland Browns', 'Kansas City Chiefs', 39, 40, '1:04pm', 'Cleveland Browns Stadium ', '3:20', 24, 24, 20, 59, 0, 30, 194, 4, 28, 40, 359, 4, 0, 20, 29, 276, 1, 1, 1, 7, 0, 0, 352, 276, 411, 470, 1, 1, 0, 0, 1, 1, 4, 38, 9, 87, 4, 11, 5, 11, 0, 0, 0, 0, '29:44', '30:16', 'Chiefs', 'outdoors', 'grass', '72,938', '86 degrees, relative humidity 48%, no wind, wind chill 0', 'Cleveland Browns', '-2.0', 36.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209080rai.htm
# Oakland Raiders
# Seattle Seahawks
# 31
# 17
# Start Time: 4:17pm
# ['Start Time', '4:17pm']
# Stadium: Network Associates Coliseum
# ['Stadium', 'Network Associates Coliseum ']
# Attendance: 53,260
# ['Attendance', '53,260']
# Time of Game: 3:16
# ['Time of Game', '3:16']
# {'Start Time': '4:17pm', 'Stadium': 'Network Associates Coliseum ', 'Attendance': '53,260', 'Time of Game': '3:16'}
# Sunday Sep 8, 2002
# 4:17pm
# Network Associates Coliseum
# 3:16
# {'Won Toss': 'Raiders', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:16', 'Attendance': '53,260', 'Weather': '70 degrees, relative humidity 47%, wind 7 mph, wind chill 0', 'Vegas Line': 'Oakland Raiders -7.5', 'Over/Under': '40.0 (over)'}
# ['Sunday Sep 8, 2002', 'Oakland Raiders', 'Seattle Seahawks', 31, 17, '4:17pm', 'Network Associates Coliseum ', '3:16', 27, 14, 40, 221, 2, 16, 43, 0, 19, 28, 214, 2, 1, 23, 32, 155, 2, 0, 2, 12, 3, 12, 202, 143, 423, 186, 1, 1, 2, 0, 2, 0, 5, 45, 13, 105, 7, 12, 1, 11, 1, 1, 2, 2, '34:51', '25:09', 'Raiders', 'outdoors', 'grass', '53,260', '70 degrees, relative humidity 47%, wind 7 mph, wind chill 0', 'Oakland Raiders', '-7.5', 40.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209080tam.htm
# Tampa Bay Buccaneers
# New Orleans Saints
# 20
# 26
# Start Time: 4:15pm
# ['Start Time', '4:15pm']
# Stadium: Raymond James Stadium
# ['Stadium', 'Raymond James Stadium ']
# Attendance: 65,554
# ['Attendance', '65,554']
# Time of Game: 3:41
# ['Time of Game', '3:41']
# {'Start Time': '4:15pm', 'Stadium': 'Raymond James Stadium ', 'Attendance': '65,554', 'Time of Game': '3:41'}
# Sunday Sep 8, 2002
# 4:15pm
# Raymond James Stadium
# 3:41
# {'Won Toss': 'Buccaneers', 'Won OT Toss': 'Buccaneers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:41', 'Attendance': '65,554', 'Weather': '90 degrees, relative humidity 57%, wind 6 mph, wind chill 0', 'Vegas Line': 'Tampa Bay Buccaneers -6.0', 'Over/Under': '37.5 (over)'}
# ['Sunday Sep 8, 2002', 'Tampa Bay Buccaneers', 'New Orleans Saints', 20, 26, '4:15pm', 'Raymond James Stadium ', '3:41', 19, 21, 21, 72, 0, 34, 118, 0, 28, 53, 278, 2, 1, 24, 42, 260, 2, 1, 3, 17, 2, 10, 261, 250, 333, 368, 1, 0, 0, 0, 1, 1, 8, 85, 5, 45, 7, 19, 10, 20, 0, 1, 0, 0, '31:29', '40:41', 'Buccaneers', 'outdoors', 'grass', '65,554', '90 degrees, relative humidity 57%, wind 6 mph, wind chill 0', 'Tampa Bay Buccaneers', '-6.0', 37.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209080was.htm
# Washington Redskins
# Arizona Cardinals
# 31
# 23
# Start Time: 1:05pm
# ['Start Time', '1:05pm']
# Stadium: FedExField
# ['Stadium', 'FedExField ']
# Attendance: 85,140
# ['Attendance', '85,140']
# Time of Game: 3:04
# ['Time of Game', '3:04']
# {'Start Time': '1:05pm', 'Stadium': 'FedExField ', 'Attendance': '85,140', 'Time of Game': '3:04'}
# Sunday Sep 8, 2002
# 1:05pm
# FedExField
# 3:04
# {'Won Toss': 'Redskins', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:04', 'Attendance': '85,140', 'Weather': '76 degrees, relative humidity 71%, wind 5 mph, wind chill 0', 'Vegas Line': 'Washington Redskins -6.0', 'Over/Under': '44.5 (over)'}
# ['Sunday Sep 8, 2002', 'Washington Redskins', 'Arizona Cardinals', 31, 23, '1:05pm', 'FedExField ', '3:04', 21, 14, 32, 122, 1, 20, 70, 1, 28, 40, 327, 3, 1, 14, 36, 187, 1, 1, 1, 7, 1, 0, 320, 187, 442, 257, 0, 0, 1, 0, 1, 1, 7, 56, 1, 5, 9, 16, 4, 13, 1, 2, 0, 0, '34:24', '25:36', 'Redskins', 'outdoors', 'grass', '85,140', '76 degrees, relative humidity 71%, wind 5 mph, wind chill 0', 'Washington Redskins', '-6.0', 44.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209090nwe.htm
# New England Patriots
# Pittsburgh Steelers
# 30
# 14
# Start Time: 9:12pm
# ['Start Time', '9:12pm']
# Stadium: Gillette Stadium
# ['Stadium', 'Gillette Stadium ']
# Attendance: 68,436
# ['Attendance', '68,436']
# Time of Game: 3:25
# ['Time of Game', '3:25']
# {'Start Time': '9:12pm', 'Stadium': 'Gillette Stadium ', 'Attendance': '68,436', 'Time of Game': '3:25'}
# Monday Sep 9, 2002
# 9:12pm
# Gillette Stadium
# 3:25
# {'Won Toss': 'Steelers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:25', 'Attendance': '68,436', 'Weather': '86 degrees, relative humidity 47%, no wind, wind chill 0', 'Vegas Line': 'Pittsburgh Steelers -2.5', 'Over/Under': '37.5 (over)'}
# ['Monday Sep 9, 2002', 'New England Patriots', 'Pittsburgh Steelers', 30, 14, '9:12pm', 'Gillette Stadium ', '3:25', 20, 20, 18, 63, 0, 24, 74, 1, 29, 43, 294, 3, 0, 25, 38, 247, 1, 3, 2, 14, 5, 38, 280, 209, 343, 283, 1, 1, 2, 2, 1, 5, 7, 88, 13, 112, 5, 13, 4, 14, 0, 0, 2, 2, '29:29', '30:31', 'Steelers', 'outdoors', 'grass', '68,436', '86 degrees, relative humidity 47%, no wind, wind chill 0', 'Pittsburgh Steelers', '-2.5', 37.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209080gnb.htm
# Green Bay Packers
# Atlanta Falcons
# 37
# 34
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Lambeau Field
# ['Stadium', 'Lambeau Field ']
# Attendance: 63,127
# ['Attendance', '63,127']
# Time of Game: 3:36
# ['Time of Game', '3:36']
# {'Start Time': '1:04pm', 'Stadium': 'Lambeau Field ', 'Attendance': '63,127', 'Time of Game': '3:36'}
# Sunday Sep 8, 2002
# 1:04pm
# Lambeau Field
# 3:36
# {'Won Toss': 'Packers', 'Won OT Toss': 'Packers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:36', 'Attendance': '63,127', 'Weather': '83 degrees, relative humidity 64%, wind 9 mph, wind chill 0', 'Vegas Line': 'Green Bay Packers -7.0', 'Over/Under': '42.5 (over)'}
# ['Sunday Sep 8, 2002', 'Green Bay Packers', 'Atlanta Falcons', 37, 34, '1:04pm', 'Lambeau Field ', '3:36', 29, 22, 38, 211, 2, 30, 180, 3, 25, 36, 284, 2, 0, 15, 23, 209, 1, 0, 2, 11, 4, 15, 273, 194, 484, 374, 3, 1, 2, 1, 1, 1, 3, 15, 4, 82, 8, 15, 4, 8, 1, 1, 0, 0, '38:50', '30:55', 'Packers', 'outdoors', 'grass', '63,127', '83 degrees, relative humidity 64%, wind 9 mph, wind chill 0', 'Green Bay Packers', '-7.0', 42.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209080htx.htm
# Houston Texans
# Dallas Cowboys
# 19
# 10
# Start Time: 8:36pm
# ['Start Time', '8:36pm']
# Stadium: Reliant Stadium
# ['Stadium', 'Reliant Stadium ']
# Attendance: 69,604
# ['Attendance', '69,604']
# Time of Game: 3:19
# ['Time of Game', '3:19']
# {'Start Time': '8:36pm', 'Stadium': 'Reliant Stadium ', 'Attendance': '69,604', 'Time of Game': '3:19'}
# Sunday Sep 8, 2002
# 8:36pm
# Reliant Stadium
# 3:19
# {'Won Toss': 'Texans', 'Roof': 'retractable roof (closed)', 'Surface': 'grass', 'Duration': '3:19', 'Attendance': '69,604', 'Vegas Line': 'Dallas Cowboys -8.5', 'Over/Under': '33.5 (under)'}
# ['Sunday Sep 8, 2002', 'Houston Texans', 'Dallas Cowboys', 19, 10, '8:36pm', 'Reliant Stadium ', '3:19', 13, 11, 35, 87, 0, 24, 155, 1, 10, 22, 145, 2, 1, 13, 30, 131, 0, 1, 6, 22, 3, 19, 123, 112, 210, 267, 1, 0, 3, 1, 1, 2, 11, 80, 9, 117, 2, 15, 2, 13, 0, 0, 0, 0, '33:55', '26:05', 'Texans', 'retractable roof (closed)', 'grass', '69,604', '', 'Dallas Cowboys', '-8.5', 33.5, 'under']
# https://www.pro-football-reference.com/boxscores/200209050nyg.htm
# New York Giants
# San Francisco 49ers
# 13
# 16
# Start Time: 8:38pm
# ['Start Time', '8:38pm']
# Stadium: Giants Stadium
# ['Stadium', 'Giants Stadium ']
# Attendance: 78,748
# ['Attendance', '78,748']
# Time of Game: 2:50
# ['Time of Game', '2:50']
# {'Start Time': '8:38pm', 'Stadium': 'Giants Stadium ', 'Attendance': '78,748', 'Time of Game': '2:50'}
# Thursday Sep 5, 2002
# 8:38pm
# Giants Stadium
# 2:50
# {'Won Toss': 'Giants', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '2:50', 'Attendance': '78,748', 'Weather': '73 degrees, relative humidity 49%, wind 7 mph, wind chill 0', 'Vegas Line': 'San Francisco 49ers -4.0', 'Over/Under': '39.0 (under)'}
# ['Thursday Sep 5, 2002', 'New York Giants', 'San Francisco 49ers', 13, 16, '8:38pm', 'Giants Stadium ', '2:50', 21, 13, 22, 43, 1, 25, 113, 0, 28, 45, 342, 0, 3, 16, 26, 166, 1, 1, 3, 24, 0, 0, 318, 166, 361, 279, 0, 0, 0, 0, 3, 1, 10, 80, 5, 29, 9, 16, 4, 12, 0, 1, 0, 0, '32:28', '27:32', 'Giants', 'outdoors', 'grass', '78,748', '73 degrees, relative humidity 49%, wind 7 mph, wind chill 0', 'San Francisco 49ers', '-4.0', 39.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209080chi.htm
# Chicago Bears
# Minnesota Vikings
# 27
# 23
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Memorial Stadium (Champaign)
# ['Stadium', 'Memorial Stadium (Champaign) ']
# Attendance: 63,226
# ['Attendance', '63,226']
# Time of Game: 3:21
# ['Time of Game', '3:21']
# {'Start Time': '1:04pm', 'Stadium': 'Memorial Stadium (Champaign) ', 'Attendance': '63,226', 'Time of Game': '3:21'}
# Sunday Sep 8, 2002
# 1:04pm
# Memorial Stadium (Champaign)
# 3:21
# {'Won Toss': 'Vikings', 'Roof': 'outdoors', 'Surface': 'astroplay', 'Duration': '3:21', 'Attendance': '63,226', 'Weather': '85 degrees, relative humidity 0%, wind 3 mph, wind chill 0', 'Vegas Line': 'Chicago Bears -4.5', 'Over/Under': '41.0 (over)'}
# ['Sunday Sep 8, 2002', 'Chicago Bears', 'Minnesota Vikings', 27, 23, '1:04pm', 'Memorial Stadium (Champaign) ', '3:21', 20, 19, 26, 80, 1, 33, 140, 1, 20, 33, 297, 2, 1, 16, 28, 234, 1, 2, 1, 9, 1, 6, 288, 228, 368, 368, 1, 1, 2, 1, 2, 3, 4, 33, 8, 52, 7, 13, 5, 13, 0, 0, 0, 0, '28:29', '31:31', 'Vikings', 'outdoors', 'astroplay', '63,226', '85 degrees, relative humidity 0%, wind 3 mph, wind chill 0', 'Chicago Bears', '-4.5', 41.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209080car.htm
# Carolina Panthers
# Baltimore Ravens
# 10
# 7
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Ericsson Stadium
# ['Stadium', 'Ericsson Stadium ']
# Attendance: 70,386
# ['Attendance', '70,386']
# Time of Game: 2:50
# ['Time of Game', '2:50']
# {'Start Time': '1:04pm', 'Stadium': 'Ericsson Stadium ', 'Attendance': '70,386', 'Time of Game': '2:50'}
# Sunday Sep 8, 2002
# 1:04pm
# Ericsson Stadium
# 2:50
# {'Won Toss': 'Panthers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '2:50', 'Attendance': '70,386', 'Weather': '78 degrees, relative humidity 59%, wind 12 mph, wind chill 0', 'Vegas Line': 'Pick', 'Over/Under': '33.0 (under)'}
# ['Sunday Sep 8, 2002', 'Carolina Panthers', 'Baltimore Ravens', 10, 7, '1:04pm', 'Ericsson Stadium ', '2:50', 15, 15, 36, 145, 0, 19, 77, 0, 12, 19, 136, 1, 0, 20, 34, 218, 1, 1, 2, 16, 2, 6, 120, 212, 265, 289, 1, 0, 0, 0, 0, 1, 6, 35, 6, 45, 5, 14, 5, 14, 0, 0, 0, 0, '33:51', '26:09', 'Panthers', 'outdoors', 'grass', '70,386', '78 degrees, relative humidity 59%, wind 12 mph, wind chill 0', 'Pi', 'k', 33.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209080oti.htm
# Tennessee Titans
# Philadelphia Eagles
# 27
# 24
# Start Time: 1:06pm
# ['Start Time', '1:06pm']
# Stadium: The Coliseum
# ['Stadium', 'The Coliseum ']
# Attendance: 68,804
# ['Attendance', '68,804']
# Time of Game: 3:20
# ['Time of Game', '3:20']
# {'Start Time': '1:06pm', 'Stadium': 'The Coliseum ', 'Attendance': '68,804', 'Time of Game': '3:20'}
# Sunday Sep 8, 2002
# 1:06pm
# The Coliseum
# 3:20
# {'Won Toss': 'Eagles', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:20', 'Attendance': '68,804', 'Weather': '83 degrees, relative humidity 60%, no wind, wind chill 0', 'Vegas Line': 'Tennessee Titans -2.0', 'Over/Under': '37.0 (over)'}
# ['Sunday Sep 8, 2002', 'Tennessee Titans', 'Philadelphia Eagles', 27, 24, '1:06pm', 'The Coliseum ', '3:20', 22, 17, 25, 61, 1, 22, 80, 0, 24, 34, 269, 2, 1, 18, 36, 212, 3, 2, 1, 2, 6, 31, 267, 181, 328, 261, 4, 3, 1, 1, 4, 3, 6, 50, 10, 113, 6, 10, 7, 15, 0, 0, 1, 1, '30:48', '29:12', 'Eagles', 'outdoors', 'grass', '68,804', '83 degrees, relative humidity 60%, no wind, wind chill 0', 'Tennessee Titans', '-2.0', 37.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209080jax.htm
# Jacksonville Jaguars
# Indianapolis Colts
# 25
# 28
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Alltel Stadium
# ['Stadium', 'Alltel Stadium ']
# Attendance: 56,595
# ['Attendance', '56,595']
# Time of Game: 3:01
# ['Time of Game', '3:01']
# {'Start Time': '1:04pm', 'Stadium': 'Alltel Stadium ', 'Attendance': '56,595', 'Time of Game': '3:01'}
# Sunday Sep 8, 2002
# 1:04pm
# Alltel Stadium
# 3:01
# {'Won Toss': 'Jaguars', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:01', 'Attendance': '56,595', 'Weather': '85 degrees, relative humidity 0%, wind 16 mph, wind chill 0', 'Vegas Line': 'Indianapolis Colts -3.5', 'Over/Under': '44.0 (over)'}
# ['Sunday Sep 8, 2002', 'Jacksonville Jaguars', 'Indianapolis Colts', 25, 28, '1:04pm', 'Alltel Stadium ', '3:01', 19, 18, 32, 118, 1, 28, 104, 0, 22, 36, 228, 2, 1, 19, 31, 211, 3, 0, 1, 3, 1, 8, 225, 203, 343, 307, 3, 1, 2, 2, 2, 2, 5, 40, 2, 14, 8, 16, 9, 14, 3, 3, 0, 0, '32:33', '27:27', 'Jaguars', 'outdoors', 'grass', '56,595', '85 degrees, relative humidity 0%, wind 16 mph, wind chill 0', 'Indianapolis Colts', '-3.5', 44.0, 'over']
# https://www.pro-football-reference.com/years/2002/week_2.htm
# https://www.pro-football-reference.com/boxscores/200209150min.htm
# Minnesota Vikings
# Buffalo Bills
# 39
# 45
# Start Time: 4:15pm
# ['Start Time', '4:15pm']
# Stadium: Hubert H. Humphrey Metrodome
# ['Stadium', 'Hubert H. Humphrey Metrodome ']
# Attendance: 64,047
# ['Attendance', '64,047']
# Time of Game: 4:05
# ['Time of Game', '4:05']
# {'Start Time': '4:15pm', 'Stadium': 'Hubert H. Humphrey Metrodome ', 'Attendance': '64,047', 'Time of Game': '4:05'}
# Sunday Sep 15, 2002
# 4:15pm
# Hubert H. Humphrey Metrodome
# 4:05
# {'Won Toss': 'Bills', 'Won OT Toss': 'Bills', 'Roof': 'dome', 'Surface': 'astroturf', 'Duration': '4:05', 'Attendance': '64,047', 'Vegas Line': 'Minnesota Vikings -3.5', 'Over/Under': '49.0 (over)'}
# ['Sunday Sep 15, 2002', 'Minnesota Vikings', 'Buffalo Bills', 39, 45, '4:15pm', 'Hubert H. Humphrey Metrodome ', '4:05', 31, 26, 39, 213, 2, 14, 31, 0, 25, 46, 281, 3, 0, 35, 49, 463, 3, 0, 5, 45, 3, 26, 236, 437, 449, 468, 5, 3, 2, 0, 3, 0, 8, 65, 6, 65, 7, 16, 4, 12, 3, 3, 0, 0, '39:49', '30:23', 'Bills', 'dome', 'astroturf', '64,047', '', 'Minnesota Vikings', '-3.5', 49.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209150pit.htm
# Pittsburgh Steelers
# Oakland Raiders
# 17
# 30
# Start Time: 8:35pm
# ['Start Time', '8:35pm']
# Stadium: Heinz Field
# ['Stadium', 'Heinz Field ']
# Attendance: 62,260
# ['Attendance', '62,260']
# Time of Game: 2:15
# ['Time of Game', '2:15']
# {'Start Time': '8:35pm', 'Stadium': 'Heinz Field ', 'Attendance': '62,260', 'Time of Game': '2:15'}
# Sunday Sep 15, 2002
# 8:35pm
# Heinz Field
# 2:15
# {'Won Toss': 'Raiders', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '2:15', 'Attendance': '62,260', 'Weather': '70 degrees, relative humidity 95%, wind 7 mph, wind chill 0', 'Vegas Line': 'Pittsburgh Steelers -4.0', 'Over/Under': '39.5 (over)'}
# ['Sunday Sep 15, 2002', 'Pittsburgh Steelers', 'Oakland Raiders', 17, 30, '8:35pm', 'Heinz Field ', '2:15', 14, 27, 18, 72, 0, 17, 95, 1, 18, 34, 201, 2, 1, 43, 65, 403, 1, 2, 0, 0, 5, 34, 201, 369, 273, 464, 4, 4, 1, 0, 5, 2, 6, 57, 7, 69, 4, 10, 12, 20, 0, 0, 0, 0, '20:26', '39:34', 'Raiders', 'outdoors', 'grass', '62,260', '70 degrees, relative humidity 95%, wind 7 mph, wind chill 0', 'Pittsburgh Steelers', '-4.0', 39.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209160was.htm
# Washington Redskins
# Philadelphia Eagles
# 7
# 37
# Start Time: 9:05pm
# ['Start Time', '9:05pm']
# Stadium: FedExField
# ['Stadium', 'FedExField ']
# Attendance: 84,982
# ['Attendance', '84,982']
# Time of Game: 3:06
# ['Time of Game', '3:06']
# {'Start Time': '9:05pm', 'Stadium': 'FedExField ', 'Attendance': '84,982', 'Time of Game': '3:06'}
# Monday Sep 16, 2002
# 9:05pm
# FedExField
# 3:06
# {'Won Toss': 'Redskins', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:06', 'Attendance': '84,982', 'Weather': '76 degrees, relative humidity 64%, wind 8 mph, wind chill 0', 'Vegas Line': 'Philadelphia Eagles -3.0', 'Over/Under': '44.0 (push)'}
# ['Monday Sep 16, 2002', 'Washington Redskins', 'Philadelphia Eagles', 7, 37, '9:05pm', 'FedExField ', '3:06', 11, 22, 18, 89, 0, 28, 168, 2, 16, 31, 119, 0, 2, 26, 38, 292, 2, 0, 4, 29, 2, 9, 90, 283, 179, 451, 1, 1, 0, 0, 3, 0, 7, 55, 4, 30, 3, 12, 7, 15, 1, 2, 0, 1, '24:37', '35:23', 'Redskins', 'outdoors', 'grass', '84,982', '76 degrees, relative humidity 64%, wind 8 mph, wind chill 0', 'Philadelphia Eagles', '-3.0', 44.0, 'push']
# https://www.pro-football-reference.com/boxscores/200209150sfo.htm
# San Francisco 49ers
# Denver Broncos
# 14
# 24
# Start Time: 4:00pm
# ['Start Time', '4:00pm']
# Stadium: 3Com Park
# ['Stadium', '3Com Park ']
# Attendance: 67,685
# ['Attendance', '67,685']
# Time of Game: 3:06
# ['Time of Game', '3:06']
# {'Start Time': '4:00pm', 'Stadium': '3Com Park ', 'Attendance': '67,685', 'Time of Game': '3:06'}
# Sunday Sep 15, 2002
# 4:00pm
# 3Com Park
# 3:06
# {'Won Toss': '49ers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:06', 'Attendance': '67,685', 'Weather': '67 degrees, relative humidity 0%, wind 11 mph, wind chill 0', 'Vegas Line': 'San Francisco 49ers -3.5', 'Over/Under': '44.0 (under)'}
# ['Sunday Sep 15, 2002', 'San Francisco 49ers', 'Denver Broncos', 14, 24, '4:00pm', '3Com Park ', '3:06', 18, 21, 20, 71, 1, 35, 201, 1, 27, 36, 205, 1, 1, 14, 19, 119, 2, 0, 2, 15, 4, 21, 190, 98, 261, 299, 2, 1, 1, 1, 2, 1, 10, 114, 3, 30, 8, 13, 5, 10, 0, 0, 0, 0, '29:27', '30:33', '49ers', 'outdoors', 'grass', '67,685', '67 degrees, relative humidity 0%, wind 11 mph, wind chill 0', 'San Francisco 49ers', '-3.5', 44.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209150rav.htm
# Baltimore Ravens
# Tampa Bay Buccaneers
# 0
# 25
# Start Time: 1:02pm
# ['Start Time', '1:02pm']
# Stadium: Ravens Stadium
# ['Stadium', 'Ravens Stadium ']
# Attendance: 69,304
# ['Attendance', '69,304']
# Time of Game: 2:55
# ['Time of Game', '2:55']
# {'Start Time': '1:02pm', 'Stadium': 'Ravens Stadium ', 'Attendance': '69,304', 'Time of Game': '2:55'}
# Sunday Sep 15, 2002
# 1:02pm
# Ravens Stadium
# 2:55
# {'Won Toss': 'Buccaneers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '2:55', 'Attendance': '69,304', 'Weather': '78 degrees, relative humidity 76%, no wind, wind chill 0', 'Vegas Line': 'Tampa Bay Buccaneers -4.5', 'Over/Under': '32.0 (under)'}
# ['Sunday Sep 15, 2002', 'Baltimore Ravens', 'Tampa Bay Buccaneers', 0, 25, '1:02pm', 'Ravens Stadium ', '2:55', 12, 17, 20, 55, 0, 30, 74, 0, 16, 38, 141, 0, 1, 24, 31, 211, 0, 0, 3, 23, 1, 6, 118, 205, 173, 279, 1, 0, 1, 0, 1, 0, 3, 25, 10, 74, 4, 15, 6, 14, 1, 2, 0, 0, '24:29', '35:31', 'Buccaneers', 'outdoors', 'grass', '69,304', '78 degrees, relative humidity 76%, no wind, wind chill 0', 'Tampa Bay Buccaneers', '-4.5', 32.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209150dal.htm
# Dallas Cowboys
# Tennessee Titans
# 21
# 13
# Start Time: 1:02pm
# ['Start Time', '1:02pm']
# Stadium: Texas Stadium
# ['Stadium', 'Texas Stadium ']
# Attendance: 62,527
# ['Attendance', '62,527']
# Time of Game: 3:10
# ['Time of Game', '3:10']
# {'Start Time': '1:02pm', 'Stadium': 'Texas Stadium ', 'Attendance': '62,527', 'Time of Game': '3:10'}
# Sunday Sep 15, 2002
# 1:02pm
# Texas Stadium
# 3:10
# {'Won Toss': 'Titans', 'Roof': 'outdoors', 'Surface': 'astroturf', 'Duration': '3:10', 'Attendance': '62,527', 'Weather': '81 degrees, relative humidity 62%, no wind, wind chill 0', 'Vegas Line': 'Tennessee Titans -3.5', 'Over/Under': '37.5 (under)'}
# ['Sunday Sep 15, 2002', 'Dallas Cowboys', 'Tennessee Titans', 21, 13, '1:02pm', 'Texas Stadium ', '3:10', 14, 19, 26, 67, 0, 26, 98, 0, 14, 24, 240, 2, 0, 23, 43, 259, 1, 1, 1, 10, 3, 24, 230, 235, 297, 333, 0, 0, 1, 0, 0, 1, 2, 15, 6, 55, 4, 12, 7, 17, 0, 0, 1, 2, '24:15', '35:45', 'Titans', 'outdoors', 'astroturf', '62,527', '81 degrees, relative humidity 62%, no wind, wind chill 0', 'Tennessee Titans', '-3.5', 37.5, 'under']
# https://www.pro-football-reference.com/boxscores/200209150cle.htm
# Cleveland Browns
# Cincinnati Bengals
# 20
# 7
# Start Time: 1:03pm
# ['Start Time', '1:03pm']
# Stadium: Cleveland Browns Stadium
# ['Stadium', 'Cleveland Browns Stadium ']
# Attendance: 73,358
# ['Attendance', '73,358']
# Time of Game: 3:14
# ['Time of Game', '3:14']
# {'Start Time': '1:03pm', 'Stadium': 'Cleveland Browns Stadium ', 'Attendance': '73,358', 'Time of Game': '3:14'}
# Sunday Sep 15, 2002
# 1:03pm
# Cleveland Browns Stadium
# 3:14
# {'Won Toss': 'Bengals', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:14', 'Attendance': '73,358', 'Weather': '72 degrees, relative humidity 68%, wind 6 mph, wind chill 0', 'Vegas Line': 'Cleveland Browns -3.5', 'Over/Under': '39.0 (under)'}
# ['Sunday Sep 15, 2002', 'Cleveland Browns', 'Cincinnati Bengals', 20, 7, '1:03pm', 'Cleveland Browns Stadium ', '3:14', 15, 28, 27, 75, 0, 31, 156, 0, 17, 30, 198, 2, 0, 26, 47, 239, 1, 3, 1, 8, 5, 38, 190, 201, 265, 357, 0, 0, 2, 0, 0, 3, 12, 87, 3, 30, 4, 12, 9, 17, 0, 1, 0, 2, '28:42', '31:18', 'Bengals', 'outdoors', 'grass', '73,358', '72 degrees, relative humidity 68%, wind 6 mph, wind chill 0', 'Cleveland Browns', '-3.5', 39.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209150car.htm
# Carolina Panthers
# Detroit Lions
# 31
# 7
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Ericsson Stadium
# ['Stadium', 'Ericsson Stadium ']
# Attendance: 71,951
# ['Attendance', '71,951']
# Time of Game: 3:01
# ['Time of Game', '3:01']
# {'Start Time': '1:04pm', 'Stadium': 'Ericsson Stadium ', 'Attendance': '71,951', 'Time of Game': '3:01'}
# Sunday Sep 15, 2002
# 1:04pm
# Ericsson Stadium
# 3:01
# {'Won Toss': 'Lions', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:01', 'Attendance': '71,951', 'Weather': '72 degrees, relative humidity 97%, wind 7 mph, wind chill 0', 'Vegas Line': 'Carolina Panthers -3.0', 'Over/Under': '35.5 (over)'}
# ['Sunday Sep 15, 2002', 'Carolina Panthers', 'Detroit Lions', 31, 7, '1:04pm', 'Ericsson Stadium ', '3:01', 20, 12, 30, 75, 2, 22, 73, 1, 21, 33, 310, 1, 0, 12, 30, 106, 0, 2, 0, 0, 6, 57, 310, 49, 385, 122, 1, 0, 2, 1, 0, 3, 4, 55, 11, 100, 3, 14, 1, 15, 0, 0, 0, 0, '33:43', '26:17', 'Lions', 'outdoors', 'grass', '71,951', '72 degrees, relative humidity 97%, wind 7 mph, wind chill 0', 'Carolina Panthers', '-3.0', 35.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209150atl.htm
# Atlanta Falcons
# Chicago Bears
# 13
# 14
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Georgia Dome
# ['Stadium', 'Georgia Dome ']
# Attendance: 68,081
# ['Attendance', '68,081']
# Time of Game: 3:10
# ['Time of Game', '3:10']
# {'Start Time': '1:04pm', 'Stadium': 'Georgia Dome ', 'Attendance': '68,081', 'Time of Game': '3:10'}
# Sunday Sep 15, 2002
# 1:04pm
# Georgia Dome
# 3:10
# {'Won Toss': 'Bears', 'Roof': 'dome', 'Surface': 'astroturf', 'Duration': '3:10', 'Attendance': '68,081', 'Vegas Line': 'Atlanta Falcons -2.5', 'Over/Under': '45.0 (under)'}
# ['Sunday Sep 15, 2002', 'Atlanta Falcons', 'Chicago Bears', 13, 14, '1:04pm', 'Georgia Dome ', '3:10', 19, 13, 30, 122, 0, 31, 106, 1, 17, 28, 166, 1, 0, 12, 24, 143, 1, 1, 4, 31, 1, 7, 135, 136, 257, 242, 3, 3, 2, 1, 3, 2, 5, 40, 7, 79, 5, 13, 4, 13, 0, 0, 0, 0, '31:25', '28:35', 'Bears', 'dome', 'astroturf', '68,081', '', 'Atlanta Falcons', '-2.5', 45.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209150nor.htm
# New Orleans Saints
# Green Bay Packers
# 35
# 20
# Start Time: 1:04pm
# ['Start Time', '1:04pm']
# Stadium: Louisiana Superdome
# ['Stadium', 'Louisiana Superdome ']
# Attendance: 67,958
# ['Attendance', '67,958']
# Time of Game: 3:07
# ['Time of Game', '3:07']
# {'Start Time': '1:04pm', 'Stadium': 'Louisiana Superdome ', 'Attendance': '67,958', 'Time of Game': '3:07'}
# Sunday Sep 15, 2002
# 1:04pm
# Louisiana Superdome
# 3:07
# {'Won Toss': 'Saints', 'Roof': 'dome', 'Surface': 'astroturf', 'Duration': '3:07', 'Attendance': '67,958', 'Vegas Line': 'Green Bay Packers -2.5', 'Over/Under': '45.5 (over)'}
# ['Sunday Sep 15, 2002', 'New Orleans Saints', 'Green Bay Packers', 35, 20, '1:04pm', 'Louisiana Superdome ', '3:07', 16, 18, 28, 146, 2, 21, 95, 0, 16, 28, 217, 2, 2, 29, 44, 270, 2, 1, 1, 6, 1, 8, 211, 262, 357, 357, 2, 0, 3, 3, 2, 4, 9, 59, 7, 73, 7, 12, 3, 13, 0, 0, 0, 2, '29:34', '30:26', 'Saints', 'dome', 'astroturf', '67,958', '', 'Green Bay Packers', '-2.5', 45.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209150kan.htm
# Kansas City Chiefs
# Jacksonville Jaguars
# 16
# 23
# Start Time: 1:00pm
# ['Start Time', '1:00pm']
# Stadium: Arrowhead Stadium
# ['Stadium', 'Arrowhead Stadium ']
# Attendance: 77,934
# ['Attendance', '77,934']
# Time of Game: 2:59
# ['Time of Game', '2:59']
# {'Start Time': '1:00pm', 'Stadium': 'Arrowhead Stadium ', 'Attendance': '77,934', 'Time of Game': '2:59'}
# Sunday Sep 15, 2002
# 1:00pm
# Arrowhead Stadium
# 2:59
# {'Won Toss': 'Jaguars', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '2:59', 'Attendance': '77,934', 'Weather': '66 degrees, relative humidity 75%, wind 7 mph, wind chill 0', 'Vegas Line': 'Kansas City Chiefs -3.5', 'Over/Under': '46.0 (under)'}
# ['Sunday Sep 15, 2002', 'Kansas City Chiefs', 'Jacksonville Jaguars', 16, 23, '1:00pm', 'Arrowhead Stadium ', '2:59', 18, 19, 28, 140, 0, 29, 130, 1, 16, 32, 199, 1, 2, 25, 36, 320, 2, 0, 1, 3, 0, 0, 196, 320, 336, 450, 0, 0, 1, 1, 2, 1, 5, 48, 5, 45, 6, 13, 7, 15, 0, 0, 1, 1, '28:16', '31:44', 'Jaguars', 'outdoors', 'grass', '77,934', '66 degrees, relative humidity 75%, wind 7 mph, wind chill 0', 'Kansas City Chiefs', '-3.5', 46.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209150sea.htm
# Seattle Seahawks
# Arizona Cardinals
# 13
# 24
# Start Time: 4:05pm
# ['Start Time', '4:05pm']
# Stadium: Seahawks Stadium
# ['Stadium', 'Seahawks Stadium ']
# Attendance: 63,104
# ['Attendance', '63,104']
# Time of Game: 3:07
# ['Time of Game', '3:07']
# {'Start Time': '4:05pm', 'Stadium': 'Seahawks Stadium ', 'Attendance': '63,104', 'Time of Game': '3:07'}
# Sunday Sep 15, 2002
# 4:05pm
# Seahawks Stadium
# 3:07
# {'Won Toss': 'Seahawks', 'Roof': 'outdoors', 'Surface': 'fieldturf', 'Duration': '3:07', 'Attendance': '63,104', 'Weather': '62 degrees, relative humidity 75%, wind 8 mph, wind chill 0', 'Vegas Line': 'Seattle Seahawks -4.0', 'Over/Under': '40.5 (under)'}
# ['Sunday Sep 15, 2002', 'Seattle Seahawks', 'Arizona Cardinals', 13, 24, '4:05pm', 'Seahawks Stadium ', '3:07', 26, 19, 29, 81, 0, 35, 249, 1, 29, 47, 352, 1, 0, 10, 22, 107, 1, 1, 1, 7, 2, 9, 345, 98, 426, 347, 2, 1, 2, 0, 1, 1, 7, 35, 7, 42, 4, 13, 6, 13, 0, 3, 0, 0, '31:00', '29:00', 'Seahawks', 'outdoors', 'fieldturf', '63,104', '62 degrees, relative humidity 75%, wind 8 mph, wind chill 0', 'Seattle Seahawks', '-4.0', 40.5, 'under']
# https://www.pro-football-reference.com/boxscores/200209150nyj.htm
# New York Jets
# New England Patriots
# 7
# 44
# Start Time: 1:03pm
# ['Start Time', '1:03pm']
# Stadium: Giants Stadium
# ['Stadium', 'Giants Stadium ']
# Attendance: 78,726
# ['Attendance', '78,726']
# Time of Game: 3:09
# ['Time of Game', '3:09']
# {'Start Time': '1:03pm', 'Stadium': 'Giants Stadium ', 'Attendance': '78,726', 'Time of Game': '3:09'}
# Sunday Sep 15, 2002
# 1:03pm
# Giants Stadium
# 3:09
# {'Won Toss': 'Patriots', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:09', 'Attendance': '78,726', 'Weather': '78 degrees, relative humidity 84%, wind 7 mph, wind chill 0', 'Vegas Line': 'New York Jets -1.0', 'Over/Under': '41.0 (over)'}
# ['Sunday Sep 15, 2002', 'New York Jets', 'New England Patriots', 7, 44, '1:03pm', 'Giants Stadium ', '3:09', 9, 24, 9, 32, 0, 40, 163, 1, 18, 33, 189, 1, 1, 25, 35, 269, 2, 1, 5, 21, 0, 0, 168, 269, 200, 432, 1, 1, 1, 1, 2, 2, 7, 55, 3, 36, 1, 12, 10, 16, 1, 3, 2, 2, '21:56', '38:04', 'Patriots', 'outdoors', 'grass', '78,726', '78 degrees, relative humidity 84%, wind 7 mph, wind chill 0', 'New York Jets', '-1.0', 41.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209150clt.htm
# Indianapolis Colts
# Miami Dolphins
# 13
# 21
# Start Time: 1:00pm
# ['Start Time', '1:00pm']
# Stadium: RCA Dome
# ['Stadium', 'RCA Dome ']
# Attendance: 56,650
# ['Attendance', '56,650']
# Time of Game: 3:00
# ['Time of Game', '3:00']
# {'Start Time': '1:00pm', 'Stadium': 'RCA Dome ', 'Attendance': '56,650', 'Time of Game': '3:00'}
# Sunday Sep 15, 2002
# 1:00pm
# RCA Dome
# 3:00
# {'Won Toss': 'Dolphins', 'Roof': 'dome', 'Surface': 'astroturf', 'Duration': '3:00', 'Attendance': '56,650', 'Vegas Line': 'Pick', 'Over/Under': '47.0 (under)'}
# ['Sunday Sep 15, 2002', 'Indianapolis Colts', 'Miami Dolphins', 13, 21, '1:00pm', 'RCA Dome ', '3:00', 29, 17, 31, 143, 0, 34, 163, 1, 26, 45, 289, 1, 3, 13, 18, 187, 2, 1, 0, 0, 1, 8, 289, 179, 432, 342, 0, 0, 2, 0, 3, 1, 5, 35, 11, 68, 4, 11, 5, 10, 1, 2, 0, 0, '31:13', '28:47', 'Dolphins', 'dome', 'astroturf', '56,650', '', 'Pi', 'k', 47.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209150sdg.htm
# San Diego Chargers
# Houston Texans
# 24
# 3
# Start Time: 4:15pm
# ['Start Time', '4:15pm']
# Stadium: Qualcomm Stadium
# ['Stadium', 'Qualcomm Stadium ']
# Attendance: 56,098
# ['Attendance', '56,098']
# Time of Game: 3:27
# ['Time of Game', '3:27']
# {'Start Time': '4:15pm', 'Stadium': 'Qualcomm Stadium ', 'Attendance': '56,098', 'Time of Game': '3:27'}
# Sunday Sep 15, 2002
# 4:15pm
# Qualcomm Stadium
# 3:27
# {'Won Toss': 'Chargers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:27', 'Attendance': '56,098', 'Weather': '74 degrees, relative humidity 78%, wind 8 mph, wind chill 0', 'Vegas Line': 'San Diego Chargers -13.5', 'Over/Under': '34.0 (under)'}
# ['Sunday Sep 15, 2002', 'San Diego Chargers', 'Houston Texans', 24, 3, '4:15pm', 'Qualcomm Stadium ', '3:27', 16, 7, 35, 124, 1, 25, 89, 0, 15, 28, 163, 1, 1, 6, 25, 87, 0, 2, 2, 20, 9, 58, 143, 29, 267, 118, 1, 0, 2, 1, 1, 3, 4, 35, 12, 73, 4, 14, 1, 14, 0, 0, 1, 2, '32:24', '27:36', 'Chargers', 'outdoors', 'grass', '56,098', '74 degrees, relative humidity 78%, wind 8 mph, wind chill 0', 'San Diego Chargers', '-13.5', 34.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209150ram.htm
# St. Louis Rams
# New York Giants
# 21
# 26
# Start Time: 3:05pm
# ['Start Time', '3:05pm']
# Stadium: Edward Jones Dome
# ['Stadium', 'Edward Jones Dome ']
# Attendance: 65,932
# ['Attendance', '65,932']
# Time of Game: 3:05
# ['Time of Game', '3:05']
# {'Start Time': '3:05pm', 'Stadium': 'Edward Jones Dome ', 'Attendance': '65,932', 'Time of Game': '3:05'}
# Sunday Sep 15, 2002
# 3:05pm
# Edward Jones Dome
# 3:05
# {'Won Toss': 'Giants', 'Roof': 'dome', 'Surface': 'astroturf', 'Duration': '3:05', 'Attendance': '65,932', 'Vegas Line': 'St. Louis Rams -12.0', 'Over/Under': '46.0 (over)'}
# ['Sunday Sep 15, 2002', 'St. Louis Rams', 'New York Giants', 21, 26, '3:05pm', 'Edward Jones Dome ', '3:05', 18, 16, 17, 92, 2, 38, 103, 0, 26, 39, 266, 1, 2, 22, 26, 307, 1, 1, 1, 6, 2, 16, 260, 291, 352, 394, 2, 2, 0, 0, 4, 1, 8, 40, 4, 30, 3, 9, 6, 15, 0, 1, 0, 0, '24:59', '35:01', 'Giants', 'dome', 'astroturf', '65,932', '', 'St. Louis Rams', '-12.0', 46.0, 'over']
# https://www.pro-football-reference.com/years/2002/week_3.htm
# https://www.pro-football-reference.com/boxscores/200209220det.htm
# Detroit Lions
# Green Bay Packers
# 31
# 37
# Start Time: 4:17pm
# ['Start Time', '4:17pm']
# Stadium: Ford Field
# ['Stadium', 'Ford Field ']
# Attendance: 61,505
# ['Attendance', '61,505']
# Time of Game: 3:26
# ['Time of Game', '3:26']
# {'Start Time': '4:17pm', 'Stadium': 'Ford Field ', 'Attendance': '61,505', 'Time of Game': '3:26'}
# Sunday Sep 22, 2002
# 4:17pm
# Ford Field
# 3:26
# {'Won Toss': 'Lions', 'Roof': 'dome', 'Surface': 'fieldturf', 'Duration': '3:26', 'Attendance': '61,505', 'Vegas Line': 'Green Bay Packers -7.5', 'Over/Under': '44.0 (over)'}
# ['Sunday Sep 22, 2002', 'Detroit Lions', 'Green Bay Packers', 31, 37, '4:17pm', 'Ford Field ', '3:26', 14, 22, 21, 95, 1, 31, 95, 0, 15, 35, 182, 2, 4, 31, 47, 357, 3, 1, 1, 6, 1, 10, 176, 347, 271, 442, 1, 1, 3, 2, 5, 3, 4, 24, 12, 88, 3, 13, 12, 21, 0, 0, 0, 0, '21:06', '38:54', 'Lions', 'dome', 'fieldturf', '61,505', '', 'Green Bay Packers', '-7.5', 44.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209220atl.htm
# Atlanta Falcons
# Cincinnati Bengals
# 30
# 3
# Start Time: 8:35pm
# ['Start Time', '8:35pm']
# Stadium: Georgia Dome
# ['Stadium', 'Georgia Dome ']
# Attendance: 68,129
# ['Attendance', '68,129']
# Time of Game: 3:06
# ['Time of Game', '3:06']
# {'Start Time': '8:35pm', 'Stadium': 'Georgia Dome ', 'Attendance': '68,129', 'Time of Game': '3:06'}
# Sunday Sep 22, 2002
# 8:35pm
# Georgia Dome
# 3:06
# {'Won Toss': 'Falcons', 'Roof': 'dome', 'Surface': 'astroturf', 'Duration': '3:06', 'Attendance': '68,129', 'Vegas Line': 'Atlanta Falcons -7.0', 'Over/Under': '42.5 (under)'}
# ['Sunday Sep 22, 2002', 'Atlanta Falcons', 'Cincinnati Bengals', 30, 3, '8:35pm', 'Georgia Dome ', '3:06', 18, 11, 36, 143, 1, 20, 66, 0, 16, 26, 174, 2, 0, 18, 42, 136, 0, 2, 1, 11, 2, 11, 163, 125, 306, 191, 0, 0, 1, 0, 0, 2, 7, 70, 8, 72, 5, 14, 5, 16, 1, 1, 0, 4, '36:45', '23:15', 'Falcons', 'dome', 'astroturf', '68,129', '', 'Atlanta Falcons', '-7.0', 42.5, 'under']
# https://www.pro-football-reference.com/boxscores/200209230tam.htm
# Tampa Bay Buccaneers
# St. Louis Rams
# 26
# 14
# Start Time: 9:07pm
# ['Start Time', '9:07pm']
# Stadium: Raymond James Stadium
# ['Stadium', 'Raymond James Stadium ']
# Attendance: 65,652
# ['Attendance', '65,652']
# Time of Game: 3:03
# ['Time of Game', '3:03']
# {'Start Time': '9:07pm', 'Stadium': 'Raymond James Stadium ', 'Attendance': '65,652', 'Time of Game': '3:03'}
# Monday Sep 23, 2002
# 9:07pm
# Raymond James Stadium
# 3:03
# {'Won Toss': 'Buccaneers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:03', 'Attendance': '65,652', 'Weather': '79 degrees, relative humidity 84%, wind 6 mph, wind chill 0', 'Vegas Line': 'St. Louis Rams -1.5', 'Over/Under': '44.0 (under)'}
# ['Monday Sep 23, 2002', 'Tampa Bay Buccaneers', 'St. Louis Rams', 26, 14, '9:07pm', 'Raymond James Stadium ', '3:03', 14, 21, 16, 63, 1, 20, 89, 2, 23, 32, 199, 1, 0, 30, 45, 301, 0, 4, 1, 10, 5, 32, 189, 269, 252, 358, 3, 1, 3, 0, 1, 4, 8, 50, 5, 33, 3, 11, 5, 13, 0, 0, 1, 1, '25:13', '34:47', 'Buccaneers', 'outdoors', 'grass', '65,652', '79 degrees, relative humidity 84%, wind 6 mph, wind chill 0', 'St. Louis Rams', '-1.5', 44.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209220htx.htm
# Houston Texans
# Indianapolis Colts
# 3
# 23
# Start Time: 1:01pm
# ['Start Time', '1:01pm']
# Stadium: Reliant Stadium
# ['Stadium', 'Reliant Stadium ']
# Attendance: 69,204
# ['Attendance', '69,204']
# Time of Game: 3:02
# ['Time of Game', '3:02']
# {'Start Time': '1:01pm', 'Stadium': 'Reliant Stadium ', 'Attendance': '69,204', 'Time of Game': '3:02'}
# Sunday Sep 22, 2002
# 1:01pm
# Reliant Stadium
# 3:02
# {'Won Toss': 'Texans', 'Roof': 'retractable roof (open)', 'Surface': 'grass', 'Duration': '3:02', 'Attendance': '69,204', 'Vegas Line': 'Indianapolis Colts -10.5', 'Over/Under': '38.0 (under)'}
# ['Sunday Sep 22, 2002', 'Houston Texans', 'Indianapolis Colts', 3, 23, '1:01pm', 'Reliant Stadium ', '3:02', 10, 16, 30, 126, 0, 27, 88, 0, 12, 22, 99, 0, 1, 21, 28, 272, 2, 0, 4, 21, 3, 21, 78, 251, 204, 339, 1, 1, 2, 2, 2, 2, 9, 67, 4, 45, 3, 13, 6, 13, 0, 0, 0, 0, '28:49', '31:11', 'Texans', 'retractable roof (open)', 'grass', '69,204', '', 'Indianapolis Colts', '-10.5', 38.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209220mia.htm
# Miami Dolphins
# New York Jets
# 30
# 3
# Start Time: 1:02pm
# ['Start Time', '1:02pm']
# Stadium: Pro Player Stadium
# ['Stadium', 'Pro Player Stadium ']
# Attendance: 73,426
# ['Attendance', '73,426']
# Time of Game: 2:57
# ['Time of Game', '2:57']
# {'Start Time': '1:02pm', 'Stadium': 'Pro Player Stadium ', 'Attendance': '73,426', 'Time of Game': '2:57'}
# Sunday Sep 22, 2002
# 1:02pm
# Pro Player Stadium
# 2:57
# {'Won Toss': 'Jets', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '2:57', 'Attendance': '73,426', 'Weather': '90 degrees, relative humidity 65%, wind 12 mph, wind chill 0', 'Vegas Line': 'Miami Dolphins -6.0', 'Over/Under': '40.5 (under)'}
# ['Sunday Sep 22, 2002', 'Miami Dolphins', 'New York Jets', 30, 3, '1:02pm', 'Pro Player Stadium ', '2:57', 21, 13, 35, 211, 2, 22, 58, 0, 16, 30, 185, 1, 0, 16, 28, 157, 0, 3, 1, 2, 3, 26, 183, 131, 394, 189, 1, 0, 1, 1, 0, 4, 7, 55, 7, 55, 6, 14, 3, 12, 0, 0, 1, 1, '32:52', '27:08', 'Jets', 'outdoors', 'grass', '73,426', '90 degrees, relative humidity 65%, wind 12 mph, wind chill 0', 'Miami Dolphins', '-6.0', 40.5, 'under']
# https://www.pro-football-reference.com/boxscores/200209220phi.htm
# Philadelphia Eagles
# Dallas Cowboys
# 44
# 13
# Start Time: 1:02pm
# ['Start Time', '1:02pm']
# Stadium: Veterans Stadium
# ['Stadium', 'Veterans Stadium ']
# Attendance: 65,537
# ['Attendance', '65,537']
# Time of Game: 3:18
# ['Time of Game', '3:18']
# {'Start Time': '1:02pm', 'Stadium': 'Veterans Stadium ', 'Attendance': '65,537', 'Time of Game': '3:18'}
# Sunday Sep 22, 2002
# 1:02pm
# Veterans Stadium
# 3:18
# {'Won Toss': 'Eagles', 'Roof': 'outdoors', 'Surface': 'fieldturf', 'Duration': '3:18', 'Attendance': '65,537', 'Weather': '82 degrees, relative humidity 58%, wind 12 mph, wind chill 0', 'Vegas Line': 'Philadelphia Eagles -10.0', 'Over/Under': '36.5 (over)'}
# ['Sunday Sep 22, 2002', 'Philadelphia Eagles', 'Dallas Cowboys', 44, 13, '1:02pm', 'Veterans Stadium ', '3:18', 26, 18, 26, 153, 1, 27, 121, 0, 26, 40, 309, 4, 0, 21, 35, 201, 0, 1, 3, 15, 3, 18, 294, 183, 447, 304, 4, 2, 3, 3, 2, 4, 3, 25, 7, 92, 3, 10, 4, 13, 1, 1, 0, 0, '29:08', '30:52', 'Eagles', 'outdoors', 'fieldturf', '65,537', '82 degrees, relative humidity 58%, wind 12 mph, wind chill 0', 'Philadelphia Eagles', '-10.0', 36.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209220den.htm
# Denver Broncos
# Buffalo Bills
# 28
# 23
# Start Time: 4:05pm
# ['Start Time', '4:05pm']
# Stadium: Invesco Field at Mile High
# ['Stadium', 'Invesco Field at Mile High ']
# Attendance: 75,359
# ['Attendance', '75,359']
# Time of Game: 3:23
# ['Time of Game', '3:23']
# {'Start Time': '4:05pm', 'Stadium': 'Invesco Field at Mile High ', 'Attendance': '75,359', 'Time of Game': '3:23'}
# Sunday Sep 22, 2002
# 4:05pm
# Invesco Field at Mile High
# 3:23
# {'Won Toss': 'Broncos', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:23', 'Attendance': '75,359', 'Weather': '59 degrees, relative humidity 48%, wind 3 mph, wind chill 0', 'Vegas Line': 'Denver Broncos -7.5', 'Over/Under': '47.0 (over)'}
# ['Sunday Sep 22, 2002', 'Denver Broncos', 'Buffalo Bills', 28, 23, '4:05pm', 'Invesco Field at Mile High ', '3:23', 22, 17, 32, 163, 1, 14, 39, 1, 19, 31, 211, 2, 0, 27, 41, 283, 2, 0, 4, 32, 4, 31, 179, 252, 342, 291, 1, 0, 1, 1, 0, 1, 9, 64, 10, 82, 3, 13, 6, 14, 1, 2, 0, 0, '32:47', '27:13', 'Broncos', 'outdoors', 'grass', '75,359', '59 degrees, relative humidity 48%, wind 3 mph, wind chill 0', 'Denver Broncos', '-7.5', 47.0, 'over']
# https://www.pro-football-reference.com/boxscores/200209220chi.htm
# Chicago Bears
# New Orleans Saints
# 23
# 29
# Start Time: 1:05pm
# ['Start Time', '1:05pm']
# Stadium: Memorial Stadium (Champaign)
# ['Stadium', 'Memorial Stadium (Champaign) ']
# Attendance: 63,216
# ['Attendance', '63,216']
# Time of Game: 3:14
# ['Time of Game', '3:14']
# {'Start Time': '1:05pm', 'Stadium': 'Memorial Stadium (Champaign) ', 'Attendance': '63,216', 'Time of Game': '3:14'}
# Sunday Sep 22, 2002
# 1:05pm
# Memorial Stadium (Champaign)
# 3:14
# {'Won Toss': 'Bears', 'Roof': 'outdoors', 'Surface': 'astroplay', 'Duration': '3:14', 'Attendance': '63,216', 'Weather': '53 degrees, relative humidity 89%, wind 6 mph, wind chill 0', 'Vegas Line': 'New Orleans Saints -2.0', 'Over/Under': '40.5 (over)'}
# ['Sunday Sep 22, 2002', 'Chicago Bears', 'New Orleans Saints', 23, 29, '1:05pm', 'Memorial Stadium (Champaign) ', '3:14', 21, 18, 30, 125, 0, 24, 73, 1, 26, 40, 236, 2, 1, 22, 34, 233, 3, 1, 1, 8, 1, 4, 228, 229, 353, 302, 2, 1, 3, 2, 2, 3, 7, 49, 10, 91, 6, 15, 4, 12, 1, 1, 0, 0, '33:59', '26:01', 'Bears', 'outdoors', 'astroplay', '63,216', '53 degrees, relative humidity 89%, wind 6 mph, wind chill 0', 'New Orleans Saints', '-2.0', 40.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209220nyg.htm
# New York Giants
# Seattle Seahawks
# 9
# 6
# Start Time: 4:14pm
# ['Start Time', '4:14pm']
# Stadium: Giants Stadium
# ['Stadium', 'Giants Stadium ']
# Attendance: 78,551
# ['Attendance', '78,551']
# Time of Game: 2:43
# ['Time of Game', '2:43']
# {'Start Time': '4:14pm', 'Stadium': 'Giants Stadium ', 'Attendance': '78,551', 'Time of Game': '2:43'}
# Sunday Sep 22, 2002
# 4:14pm
# Giants Stadium
# 2:43
# {'Won Toss': 'Seahawks', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '2:43', 'Attendance': '78,551', 'Weather': '82 degrees, relative humidity 49%, wind 8 mph, wind chill 0', 'Vegas Line': 'New York Giants -5.5', 'Over/Under': '39.0 (under)'}
# ['Sunday Sep 22, 2002', 'New York Giants', 'Seattle Seahawks', 9, 6, '4:14pm', 'Giants Stadium ', '2:43', 21, 7, 35, 94, 0, 18, 40, 0, 23, 38, 282, 0, 0, 16, 25, 118, 0, 1, 3, 25, 2, 13, 257, 105, 351, 145, 1, 0, 0, 0, 0, 1, 3, 24, 6, 37, 8, 18, 4, 12, 0, 1, 0, 0, '36:50', '23:10', 'Seahawks', 'outdoors', 'grass', '78,551', '82 degrees, relative humidity 49%, wind 8 mph, wind chill 0', 'New York Giants', '-5.5', 39.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209220nwe.htm
# New England Patriots
# Kansas City Chiefs
# 41
# 38
# Start Time: 1:02pm
# ['Start Time', '1:02pm']
# Stadium: Gillette Stadium
# ['Stadium', 'Gillette Stadium ']
# Attendance: 68,436
# ['Attendance', '68,436']
# Time of Game: 3:25
# ['Time of Game', '3:25']
# {'Start Time': '1:02pm', 'Stadium': 'Gillette Stadium ', 'Attendance': '68,436', 'Time of Game': '3:25'}
# Sunday Sep 22, 2002
# 1:02pm
# Gillette Stadium
# 3:25
# {'Won Toss': 'Patriots', 'Won OT Toss': 'Patriots', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:25', 'Attendance': '68,436', 'Weather': '80 degrees, relative humidity 0%, wind 20 mph, wind chill 0', 'Vegas Line': 'New England Patriots -8.5', 'Over/Under': '43.5 (over)'}
# ['Sunday Sep 22, 2002', 'New England Patriots', 'Kansas City Chiefs', 41, 38, '1:02pm', 'Gillette Stadium ', '3:25', 27, 21, 20, 97, 1, 34, 221, 2, 39, 55, 410, 4, 1, 16, 25, 149, 3, 2, 4, 11, 3, 21, 399, 128, 496, 349, 2, 0, 1, 1, 1, 3, 12, 100, 1, 5, 8, 17, 6, 11, 0, 0, 0, 0, '37:39', '27:01', 'Patriots', 'outdoors', 'grass', '68,436', '80 degrees, relative humidity 0%, wind 20 mph, wind chill 0', 'New England Patriots', '-8.5', 43.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209220oti.htm
# Tennessee Titans
# Cleveland Browns
# 28
# 31
# Start Time: 1:03pm
# ['Start Time', '1:03pm']
# Stadium: The Coliseum
# ['Stadium', 'The Coliseum ']
# Attendance: 68,804
# ['Attendance', '68,804']
# {'Start Time': '1:03pm', 'Stadium': 'The Coliseum ', 'Attendance': '68,804'}
# Sunday Sep 22, 2002
# 1:03pm
# The Coliseum
#
# {'Won Toss': 'Browns', 'Won OT Toss': 'Browns', 'Roof': 'outdoors', 'Surface': 'grass', 'Attendance': '68,804', 'Weather': '72 degrees, relative humidity 78%, wind 9 mph, wind chill 0', 'Vegas Line': 'Tennessee Titans -4.5', 'Over/Under': '40.5 (over)'}
# ['Sunday Sep 22, 2002', 'Tennessee Titans', 'Cleveland Browns', 28, 31, '1:03pm', 'The Coliseum ', '', 13, 26, 34, 86, 1, 20, 92, 0, 15, 23, 107, 2, 0, 36, 50, 326, 3, 1, 1, 6, 3, 15, 101, 311, 187, 403, 1, 0, 4, 3, 0, 4, 13, 96, 7, 57, 3, 13, 8, 15, 1, 1, 0, 0, '33:11', '31:02', 'Browns', 'outdoors', 'grass', '68,804', '72 degrees, relative humidity 78%, wind 9 mph, wind chill 0', 'Tennessee Titans', '-4.5', 40.5, 'over']
# https://www.pro-football-reference.com/boxscores/200209220sfo.htm
# San Francisco 49ers
# Washington Redskins
# 20
# 10
# Start Time: 4:15pm
# ['Start Time', '4:15pm']
# Stadium: 3Com Park
# ['Stadium', '3Com Park ']
# Attendance: 67,541
# ['Attendance', '67,541']
# Time of Game: 3:02
# ['Time of Game', '3:02']
# {'Start Time': '4:15pm', 'Stadium': '3Com Park ', 'Attendance': '67,541', 'Time of Game': '3:02'}
# Sunday Sep 22, 2002
# 4:15pm
# 3Com Park
# 3:02
# {'Won Toss': '49ers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:02', 'Attendance': '67,541', 'Weather': '65 degrees, relative humidity 81%, wind 5 mph, wind chill 0', 'Vegas Line': 'San Francisco 49ers -10.0', 'Over/Under': '44.0 (under)'}
# ['Sunday Sep 22, 2002', 'San Francisco 49ers', 'Washington Redskins', 20, 10, '4:15pm', '3Com Park ', '3:02', 22, 12, 41, 252, 2, 16, 57, 0, 15, 28, 125, 0, 1, 18, 30, 183, 1, 1, 2, 11, 3, 23, 114, 160, 366, 217, 0, 0, 3, 2, 1, 3, 5, 50, 4, 35, 6, 14, 4, 12, 0, 0, 0, 0, '35:55', '24:05', '49ers', 'outdoors', 'grass', '67,541', '65 degrees, relative humidity 81%, wind 5 mph, wind chill 0', 'San Francisco 49ers', '-10.0', 44.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209220crd.htm
# Arizona Cardinals
# San Diego Chargers
# 15
# 23
# Start Time: 4:05pm
# ['Start Time', '4:05pm']
# Stadium: Sun Devil Stadium
# ['Stadium', 'Sun Devil Stadium ']
# Attendance: 28,980
# ['Attendance', '28,980']
# Time of Game: 3:08
# ['Time of Game', '3:08']
# {'Start Time': '4:05pm', 'Stadium': 'Sun Devil Stadium ', 'Attendance': '28,980', 'Time of Game': '3:08'}
# Sunday Sep 22, 2002
# 4:05pm
# Sun Devil Stadium
# 3:08
# {'Won Toss': 'Chargers', 'Roof': 'outdoors', 'Surface': 'grass', 'Duration': '3:08', 'Attendance': '28,980', 'Weather': '100 degrees, relative humidity 10%, no wind, wind chill 0', 'Vegas Line': 'San Diego Chargers -2.5', 'Over/Under': '39.0 (under)'}
# ['Sunday Sep 22, 2002', 'Arizona Cardinals', 'San Diego Chargers', 15, 23, '4:05pm', 'Sun Devil Stadium ', '3:08', 15, 19, 21, 97, 0, 34, 125, 2, 16, 36, 229, 2, 2, 17, 31, 181, 0, 1, 3, 29, 2, 17, 200, 164, 297, 289, 1, 1, 0, 0, 3, 1, 2, 25, 8, 80, 7, 16, 7, 15, 0, 1, 0, 0, '25:43', '34:17', 'Chargers', 'outdoors', 'grass', '28,980', '100 degrees, relative humidity 10%, no wind, wind chill 0', 'San Diego Chargers', '-2.5', 39.0, 'under']
# https://www.pro-football-reference.com/boxscores/200209220min.htm
# Minnesota Vikings
# Carolina Panthers
# 14
# 21
# Start Time: 1:00pm
# ['Start Time', '1:00pm']
# Stadium: Hubert H. Humphrey Metrodome
# ['Stadium', 'Hubert H. Humphrey Metrodome ']
# Attendance: 63,945
# ['Attendance', '63,945']
# Time of Game: 2:58
# ['Time of Game', '2:58']
# {'Start Time': '1:00pm', 'Stadium': 'Hubert H. Humphrey Metrodome ', 'Attendance': '63,945', 'Time of Game': '2:58'}
# Sunday Sep 22, 2002
# 1:00pm
# Hubert H. Humphrey Metrodome
# 2:58
# {'Won Toss': 'Panthers', 'Roof': 'dome', 'Surface': 'astroturf', 'Duration': '2:58', 'Attendance': '63,945', 'Vegas Line': 'Minnesota Vikings -6.5', 'Over/Under': '44.5 (under)'}
# ['Sunday Sep 22, 2002', 'Minnesota Vikings', 'Carolina Panthers', 14, 21, '1:00pm', 'Hubert H. Humphrey Metrodome ', '2:58', 13, 20, 18, 73, 1, 33, 164, 2, 19, 30, 191, 1, 4, 20, 30, 221, 1, 2, 5, 14, 3, 15, 177, 206, 250, 370, 4, 1, 0, 0, 5, 2, 6, 55, 6, 41, 2, 10, 6, 15, 0, 1, 0, 0, '24:36', '35:24', 'Panthers', 'dome', 'astroturf', '63,945', '', 'Minnesota Vikings', '-6.5', 44.5, 'under']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-a8f6fadaeb5d> in <module>
#     228     df['game_time'] = df['game_time'].dt.time
#     229
# --> 230     df['duration'] = pd.to_datetime(df['duration'], format='%M:%S').dt.time
#     231     df['home_time_possession'] = pd.to_datetime(df['home_time_possession'], format='%M:%S').dt.time
#     232     df['away_time_possession'] = pd.to_datetime(df['away_time_possession'], format='%M:%S').dt.time
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     726             result = arg.map(cache_array)
#     727         else:
# --> 728             values = convert_listlike(arg._values, format)
#     729             result = arg._constructor(values, index=arg.index, name=arg.name)
#     730     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     434             except (ValueError, TypeError):
# --> 435                 raise e
#     436
#     437     if result is None:
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     398                 try:
#     399                     result, timezones = array_strptime(
# --> 400                         arg, format, exact=exact, errors=errors
#     401                     )
#     402                     if "%Z" in format or "%z" in format:
#
# pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '' does not match format '%M:%S' (match)

# %%
print('Insert webdriver')

driver = webdriver.Chrome()
YEAR = 2019

scrape_data(driver, year)
